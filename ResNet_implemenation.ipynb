# %%
#import required Libaries
import os
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import layers, regularizers, models

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("marquis03/bdd100k-scenario-classification")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'bdd100k-scenario-classification' dataset.
# Path to dataset files: /kaggle/input/bdd100k-scenario-classification

# %%
print(os.listdir(path))
# Out:
# ['val', 'test', 'train']

# %%
train_path = os.path.join(path, "train")
print(os.listdir(train_path))
# Out:
# ['unknown', 'city street', 'highway', 'gas stations', 'parking lot', 'residential', 'tunnel']

# %%
# loading and spliting the dataset for train/test/validation

img_size = (224, 224)
batch_size = 32

train_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(path, "train"),
    validation_split=0.3,
    subset="training",
    seed=42,
    image_size=img_size,
    batch_size=batch_size
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(path, "train"),
    validation_split=0.3,
    subset="validation",
    seed=42,
    image_size=img_size,
    batch_size=batch_size
)
val_dataset = tf.keras.utils.image_dataset_from_directory(
    os.path.join(path, "val"),
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 69863 files belonging to 7 classes.
# Using 48905 files for training.
# Found 69863 files belonging to 7 classes.
# Using 20958 files for validation.
# Found 10000 files belonging to 7 classes.

# %%
# Preprocess the data
normalization_layer = tf.keras.layers.Rescaling(1./255)

AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.map(lambda x, y: (normalization_layer(x), y))
test_dataset  = test_dataset.map(lambda x, y: (normalization_layer(x), y))
val_dataset   = val_dataset.map(lambda x, y: (normalization_layer(x), y))

# %%
# Build Resnet Block
class ResidualBlock(tf.keras.layers.Layer):
    def __init__(self, filters, stride=1, l2=None):
        super().__init__()

        self.conv1 = layers.Conv2D(filters, 3, strides=stride, padding='same', kernel_regularizer=l2)
        self.bn1 = layers.BatchNormalization()

        self.conv2 = layers.Conv2D(filters, 3, strides=1, padding='same', kernel_regularizer=l2)
        self.bn2 = layers.BatchNormalization()


        if stride != 1:
            self.shortcut = tf.keras.Sequential([
                layers.Conv2D(filters, 1, strides=stride, padding='same'),
                layers.BatchNormalization()
            ])
        else:
            self.shortcut = lambda x: x   # identity

    def call(self, x):
        shortcut = self.shortcut(x)

        x = tf.nn.relu(self.bn1(self.conv1(x)))
        x = self.bn2(self.conv2(x))

        x = x + shortcut
        return tf.nn.relu(x)

# %%
# Build Resnet Model
def build_resnet(input_shape=(224,224,3), num_classes=7):
    l2 = regularizers.l2(1e-4)

    inputs = layers.Input(shape=input_shape)

    # Initial layer
    x = layers.Conv2D(64, 7, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    # Residual stages
    # Stage 1
    x = ResidualBlock(64, stride=1, l2=l2)(x)
    x = ResidualBlock(64, stride=1, l2=l2)(x)

    # Stage 2
    x = ResidualBlock(128, stride=2, l2=l2)(x)
    x = ResidualBlock(128, stride=1, l2=l2)(x)

    # Stage 3
    x = ResidualBlock(256, stride=2, l2=l2)(x)
    x = ResidualBlock(256, stride=1, l2=l2)(x)

    # Stage 4
    x = ResidualBlock(512, stride=2, l2=l2)(x)
    x = ResidualBlock(512, stride=1, l2=l2)(x)

    # Classification head
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=l2
    )(x)

    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)

    return model

# %%
# Configuring the model howto learn
model = build_resnet()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 112, 112, 64)   │         9,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block (ResidualBlock)  │ (None, 56, 56, 64)     │        74,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_1                │ (None, 56, 56, 64)     │        74,368 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_2                │ (None, 28, 28, 128)    │       231,296 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_3                │ (None, 28, 28, 128)    │       296,192 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_4                │ (None, 14, 14, 256)    │       921,344 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_5                │ (None, 14, 14, 256)    │     1,182,208 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_6                │ (None, 7, 7, 512)      │     3,677,696 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ residual_block_7                │ (None, 7, 7, 512)      │     4,723,712 │
# │ (ResidualBlock)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │           903 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,257,479 (42.94 MB)
#  Trainable params: 11,247,879 (42.91 MB)
#  Non-trainable params: 9,600 (37.50 KB)

# %%
# Train the model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10
)
# Out:
# Epoch 1/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 333s 215ms/step - accuracy: 0.6568 - loss: 1.2460 - val_accuracy: 0.6745 - val_loss: 1.3765
# Epoch 2/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.6941 - loss: 1.1028 - val_accuracy: 0.6939 - val_loss: 1.1251
# Epoch 3/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.7123 - loss: 1.0004 - val_accuracy: 0.5530 - val_loss: 1.1315
# Epoch 4/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.7224 - loss: 0.9197 - val_accuracy: 0.5212 - val_loss: 1.1617
# Epoch 5/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.7350 - loss: 0.8515 - val_accuracy: 0.6628 - val_loss: 0.9790
# Epoch 6/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.7506 - loss: 0.7925 - val_accuracy: 0.7017 - val_loss: 0.9595
# Epoch 7/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.7742 - loss: 0.7272 - val_accuracy: 0.7000 - val_loss: 0.9582
# Epoch 8/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 328s 214ms/step - accuracy: 0.8029 - loss: 0.6508 - val_accuracy: 0.6073 - val_loss: 1.0989
# Epoch 9/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 327s 214ms/step - accuracy: 0.8429 - loss: 0.5582 - val_accuracy: 0.6239 - val_loss: 1.1816
# Epoch 10/10
# 1529/1529 ━━━━━━━━━━━━━━━━━━━━ 326s 213ms/step - accuracy: 0.8726 - loss: 0.4889 - val_accuracy: 0.6614 - val_loss: 1.2673

# %%
# Evaluate model performance
test_loss, test_acc = model.evaluate(test_dataset)
print("Test Accuracy:", test_acc)
# Out:
# 655/655 ━━━━━━━━━━━━━━━━━━━━ 29s 44ms/step - accuracy: 0.6724 - loss: 1.2225
# Test Accuracy: 0.6724401116371155

# %% [markdown]
# Accuracy and Loss plot

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# Accuracy plot
plt.figure(figsize=(10,6))
plt.plot(hist['epoch'], hist['accuracy'], label='Train Accuracy')
plt.plot(hist['epoch'], hist['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('ResNet Training vs Validation Accuracy')
plt.legend()
plt.show()

# Loss plot
plt.figure(figsize=(10,6))
plt.plot(hist['epoch'], hist['loss'], label='Train Loss')
plt.plot(hist['epoch'], hist['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('ResNet Training vs Validation Loss')
plt.legend()
plt.show()
